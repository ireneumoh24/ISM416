# %% [markdown]
# ## IRENE UMOH 17100310866

# %% [markdown]
# ## Website 1 Scraping and Summarization

# %%
import requests
from bs4 import BeautifulSoup
from gensim.summarization import summarize

# %%
url = 'https://theconversation.com/waffles-and-mochi-why-childrens-food-shows-need-to-focus-on-healthy-eating-157360'

# %%
page = requests.get(url).text

# %%
soup = BeautifulSoup(page)

# %%
head = soup.find('h1').get_text()

# %%
p_tags = soup.find_all('p')

# %%
texts = [tags.get_text().strip() for tags in p_tags]

# %%
print(texts)
# Out:
# ['Programme Lead Nutrition and Health, Edge Hill University', 'Hazel Flight does not work for, consult, own shares in or receive funding from any company or organisation that would benefit from this article, and has disclosed no relevant affiliations beyond their academic appointment.', '', 'Edge Hill University provides funding as a member of The Conversation UK.', 'The Conversation is funded by the National Research Foundation, eight universities, including the Cape Peninsula University of Technology, Rhodes University, Stellenbosch University and the Universities of Cape Town, Johannesburg, Kwa-Zulu Natal, Pretoria, and South Africa. It is hosted by the Universities of the Witwatersrand and Western Cape, the African Population and Health Research Centre and the Nigerian Academy of Science. The Bill & Melinda Gates Foundation is a Strategic Partner. more', 'Michelle Obama’s new TV show, Waffles and Mochi, aimed at young children, is a fabulous idea. The idea is to show children where food comes from and some ways of cooking it from scratch – instead of just buying pre-made meals from the supermarket.', 'How a child eats can have a serious impact on their overall health and wellbeing throughout life. So, children should be encouraged to enjoy a healthy lifestyle, and to eat a varied diet that is rich in nutrients. And their parents should be made aware of meeting dietary requirements in a way that supports a long and healthy life. Habits learned at a young age, such as healthy eating, have been proven to carry through to adulthood.', 'I am extremely passionate about educating children (and their parents) about good nutrition. A part of this is encouraging them to cook and try new foods, which are nutritious and beneficial to them. Children are like little sponges. They require stimulation and encouragement to soak up information and learn by experience. So a bright and entertaining TV show that also informs is a great idea.', 'Waffles and Mochi are two puppets who are determined to learn to cook and prepare fresh meals after living on a pretty terrible diet of ice cream. They travel the world in their magical flying shopping cart and meet celebrity chefs, including Jose Andres from Spain and Massimo Bottura from Italy. The series has some inspirational ideas and is excellent in introducing children and adults to different cultures and foods.', 'I believe that television is an effective teaching tool, which is not always used to its best advantage. Young children will sit and watch and take on board what they see and hear, especially if the show includes fast-moving action, lively music and colourful animation. It can also teach important values and life lessons. And, if used appropriately and of good quality, TV shows can create powerful messages.', 'So it’s good that Waffles and Mochi are never put off by the foods they come across on their travels. Instead, they are always up for giving them a try – a great example for some fussy eaters. They also say out loud what they are experiencing. So for example, one may like the taste but not the texture.', 'Advice for parents of picky eaters is to avoid being anxious and instead always be positive. Leading by example, like Mochi and Waffles, is a great way to do this.', 'Teaching children about where their food is from is also brilliant. It educates children that food is not just from a shelf in the supermarket or the nearest takeaway.', 'However, having watched a few episodes, I was concerned the show didn’t do enough to encourage as healthy a diet as possible. For instance, in one episode sugar was added to tomatoes. Yet there are other ways of making tomatoes taste sweeter, such as roasting them, that don’t involve an ingredient most countries are trying to reduce consumption of.', 'In another episode, the focus is salt. Although it was suggested that salt should be added in moderation, the overarching message to children was that you needed salt to make the food taste better. W ...

# %%
sentence_list = [sentence for sentence in texts if not '\n' in sentence]

# %%
#for sentence in the original document, if it does not contain a new line, return the sentence

# %%
sentence_list = [sentence for sentence in sentence_list if '.' in sentence]

# %%
sentence_list
# Out:
# ['Hazel Flight does not work for, consult, own shares in or receive funding from any company or organisation that would benefit from this article, and has disclosed no relevant affiliations beyond their academic appointment.',
#  'Edge Hill University provides funding as a member of The Conversation UK.',
#  'The Conversation is funded by the National Research Foundation, eight universities, including the Cape Peninsula University of Technology, Rhodes University, Stellenbosch University and the Universities of Cape Town, Johannesburg, Kwa-Zulu Natal, Pretoria, and South Africa. It is hosted by the Universities of the Witwatersrand and Western Cape, the African Population and Health Research Centre and the Nigerian Academy of Science. The Bill & Melinda Gates Foundation is a Strategic Partner. more',
#  'Michelle Obama’s new TV show, Waffles and Mochi, aimed at young children, is a fabulous idea. The idea is to show children where food comes from and some ways of cooking it from scratch – instead of just buying pre-made meals from the supermarket.',
#  'How a child eats can have a serious impact on their overall health and wellbeing throughout life. So, children should be encouraged to enjoy a healthy lifestyle, and to eat a varied diet that is rich in nutrients. And their parents should be made aware of meeting dietary requirements in a way that supports a long and healthy life. Habits learned at a young age, such as healthy eating, have been proven to carry through to adulthood.',
#  'I am extremely passionate about educating children (and their parents) about good nutrition. A part of this is encouraging them to cook and try new foods, which are nutritious and beneficial to them. Children are like little sponges. They require stimulation and encouragement to soak up information and learn by experience. So a bright and entertaining TV show that also informs is a great idea.',
#  'Waffles and Mochi are two puppets who are determined to learn to cook and prepare fresh meals after living on a pretty terrible diet of ice cream. They travel the world in their magical flying shopping cart and meet celebrity chefs, including Jose Andres from Spain and Massimo Bottura from Italy. The series has some inspirational ideas and is excellent in introducing children and adults to different cultures and foods.',
#  'I believe that television is an effective teaching tool, which is not always used to its best advantage. Young children will sit and watch and take on board what they see and hear, especially if the show includes fast-moving action, lively music and colourful animation. It can also teach important values and life lessons. And, if used appropriately and of good quality, TV shows can create powerful messages.',
#  'So it’s good that Waffles and Mochi are never put off by the foods they come across on their travels. Instead, they are always up for giving them a try – a great example for some fussy eaters. They also say out loud what they are experiencing. So for example, one may like the taste but not the texture.',
#  'Advice for parents of picky eaters is to avoid being anxious and instead always be positive. Leading by example, like Mochi and Waffles, is a great way to do this.',
#  'Teaching children about where their food is from is also brilliant. It educates children that food is not just from a shelf in the supermarket or the nearest takeaway.',
#  'However, having watched a few episodes, I was concerned the show didn’t do enough to encourage as healthy a diet as possible. For instance, in one episode sugar was added to tomatoes. Yet there are other ways of making tomatoes taste sweeter, such as roasting them, that don’t involve an ingredient most countries are trying to reduce consumption of.',
#  'In another episode, the focus is salt. Although it was suggested that salt should be added in moderation, the overarching message to children was that you needed salt to make the food taste better. While adding salt when cooking is very common, the reality is most people eat too much of it. So dedicating a whole episode to it doesn’t really fit with a message of encouraging healthy eating when, again, there are global initiatives to reduce our salt intake.',
#  'Programmes featuring healthy foods can be an important ingredient in supporting children to make healthier food choices throughout life. A study carried out in the Netherlands found that children who watched television programmes with healthy foods were more likely to choose healthy options for snacks.',
#  'Waffles and Mochi is an excellent platform, widely available across the world, which could educate children about what foods are good and what their health benefits are, alongside where they come from. For example, tomatoes are an excellent source of vitamins and minerals and have many health benefits(while adding sugar can counteract this).',
#  'Our children’s health should be of prime concern and good and healthy habits need to be instilled as early in life as possible. Children are still eating too many calories, including sugar, and often the wrong foods and so parents need to be provided with the correct knowledge and information to support their child’s health and wellbeing. With the continuing rise in childhood obesity it is a subject which needs serious consideration.',
#  'Waffles and Mochi certainly has inspired some thought and no doubt will hopefully encourage children (and adults) to cook and try new food as well as igniting their interest in foods from around the world. But the show could go further to encourage children to eat more healthily in the way Michelle Obama has become known for.',
#  'Write an article and join a growing community of more than 127,600 academics and researchers from 4,035 institutions.',
#  'Copyright © 2010–2021, The Conversation Africa, Inc.']

# %%
article = ''.join(sentence_list)

# %%
summary = summarize(article, ratio=0.15)

print('Length of original article: {}'.format(len(article)))
print('Length of summary: {}\n'.format(len(summary)))  
print('Headline: {} \n'.format(head))
print('Article Summary: \n{}'.format(summary))
# Out:
# Length of original article: 5725
# Length of summary: 969
#
# Headline:
#
#             Waffles and Mochi: why children’s food shows need to focus on healthy eating
#
#
#
# Article Summary:
# The idea is to show children where food comes from and some ways of cooking it from scratch – instead of just buying pre-made meals from the supermarket.How a child eats can have a serious impact on their overall health and wellbeing throughout life.
# Leading by example, like Mochi and Waffles, is a great way to do this.Teaching children about where their food is from is also brilliant.
# A study carried out in the Netherlands found that children who watched television programmes with healthy foods were more likely to choose healthy options for snacks.Waffles and Mochi is an excellent platform, widely available across the world, which could educate children about what foods are good and what their health benefits are, alongside where they come from.
# Children are still eating too many calories, including sugar, and often the wrong foods and so parents need to be provided with the correct knowledge and information to support their child’s health and wellbeing.

# %%
import spacy
nlp = spacy.load('en_core_web_sm')

# %%
doc = nlp(summary)

# %% [markdown]
# ## Tokenization

# %%
for token in doc:
    print(token.text, '--->', spacy.explain(token.text))
# Out:
# The ---> None
# idea ---> None
# is ---> None
# to ---> None
# show ---> None
# children ---> None
# where ---> None
# food ---> None
# comes ---> None
# from ---> None
# and ---> None
# some ---> None
# ways ---> None
# of ---> None
# cooking ---> None
# it ---> None
# from ---> None
# scratch ---> None
# – ---> None
# instead ---> None
# of ---> None
# just ---> None
# buying ---> None
# pre ---> None
# - ---> None
# made ---> None
# meals ---> None
# from ---> None
# the ---> None
# supermarket ---> None
# . ---> punctuation mark, sentence closer
# How ---> None
# a ---> None
# child ---> None
# eats ---> None
# can ---> None
# have ---> None
# a ---> None
# serious ---> None
# impact ---> None
# on ---> None
# their ---> None
# overall ---> None
# health ---> None
# and ---> None
# wellbeing ---> None
# throughout ---> None
# life ---> None
# . ---> punctuation mark, sentence closer
#
#  ---> None
# Leading ---> None
# by ---> None
# example ---> None
# , ---> punctuation mark, comma
# like ---> None
# Mochi ---> None
# and ---> None
# Waffles ---> None
# , ---> punctuation mark, comma
# is ---> None
# a ---> None
# great ---> None
# way ---> None
# to ---> None
# do ---> None
# this ---> None
# . ---> punctuation mark, sentence closer
# Teaching ---> None
# children ---> None
# about ---> None
# where ---> None
# their ---> None
# food ---> None
# is ---> None
# from ---> None
# is ---> None
# also ---> None
# brilliant ---> None
# . ---> punctuation mark, sentence closer
#
#  ---> None
# A ---> None
# study ---> None
# carried ---> None
# out ---> None
# in ---> None
# the ---> None
# Netherlands ---> None
# found ---> None
# that ---> None
# children ---> None
# who ---> None
# watched ---> None
# television ---> None
# programmes ---> None
# with ---> None
# healthy ---> None
# foods ---> None
# were ---> None
# more ---> None
# likely ---> None
# to ---> None
# choose ---> None
# healthy ---> None
# options ---> None
# for ---> None
# snacks ---> None
# . ---> punctuation mark, sentence closer
# Waffles ---> None
# and ---> None
# Mochi ---> None
# is ---> None
# an ---> None
# excellent ---> None
# platform ---> None
# , ---> punctuation mark, comma
# widely ---> None
# available ---> None
# across ---> None
# the ---> None
# world ---> None
# , ---> punctuation mark, comma
# which ---> None
# could ---> None
# educate ---> None
# children ---> None
# about ---> None
# what ---> None
# foods ---> None
# are ---> None
# good ---> None
# and ---> None
# what ---> None
# their ---> None
# health ---> None
# benefits ---> None
# are ---> None
# , ---> punctuation mark, comma
# alongside ---> None
# where ---> None
# they ---> None
# come ---> None
# from ---> None
# . ---> punctuation mark, sentence closer
#
#  ---> None
# Children ---> None
# are ---> None
# still ---> None
# eating ---> None
# too ---> None
# many ---> None
# calories ---> None
# , ---> punctuation mark, comma
# including ---> None
# sugar ---> None
# , ---> punctuation mark, comma
# and ---> None
# often ---> None
# the ---> None
# wrong ---> None
# foods ---> None
# and ---> None
# so ---> None
# parents ---> None
# need ---> None
# to ---> None
# be ---> None
# provided ---> None
# with ---> None
# the ---> None
# correct ---> None
# knowledge ---> None
# and ---> None
# information ---> None
# to ---> None
# support ---> None
# their ---> None
# child ---> None
# ’s ---> None
# health ---> None
# and ---> None
# wellbeing ---> None
# . ---> punctuation mark, sentence closer

# %% [markdown]
# ## Dependency Parsing

# %%
for token in doc:
    print(token.text, '--->', token.dep_, '--->', spacy.explain(token.dep))
# Out:
# The ---> det ---> None
# idea ---> nsubj ---> None
# is ---> ROOT ---> None
# to ---> aux ---> None
# show ---> xcomp ---> None
# children ---> dobj ---> None
# where ---> advmod ---> None
# food ---> nsubj ---> None
# comes ---> relcl ---> None
# from ---> prep ---> None
# and ---> cc ---> None
# some ---> det ---> None
# ways ---> conj ---> None
# of ---> prep ---> None
# cooking ---> pcomp ---> None
# it ---> dobj ---> None
# from ---> prep ---> None
# scratch ---> pobj ---> None
# – ---> punct ---> None
# instead ---> advmod ---> None
# of ---> prep ---> None
# just ---> advmod ---> None
# buying ---> pcomp ---> None
# pre ---> dobj ---> None
# - ---> amod ---> None
# made ---> amod ---> None
# meals ---> dobj ---> None
# from ---> prep ---> None
# the ---> det ---> None
# supermarket ---> pobj ---> None
# . ---> punct ---> None
# How ---> advmod ---> None
# a ---> det ---> None
# child ---> nsubj ---> None
# eats ---> csubj ---> None
# can ---> aux ---> None
# have ---> ROOT ---> None
# a ---> det ---> None
# serious ---> amod ---> None
# impact ---> dobj ---> None
# on ---> prep ---> None
# their ---> poss ---> None
# overall ---> amod ---> None
# health ---> pobj ---> None
# and ---> cc ---> None
# wellbeing ---> conj ---> None
# throughout ---> prep ---> None
# life ---> pobj ---> None
# . ---> punct ---> None
#
#  ---> punct ---> None
# Leading ---> advcl ---> None
# by ---> prep ---> None
# example ---> pobj ---> None
# , ---> punct ---> None
# like ---> prep ---> None
# Mochi ---> pobj ---> None
# and ---> cc ---> None
# Waffles ---> conj ---> None
# , ---> punct ---> None
# is ---> ROOT ---> None
# a ---> det ---> None
# great ---> amod ---> None
# way ---> attr ---> None
# to ---> aux ---> None
# do ---> relcl ---> None
# this ---> dobj ---> None
# . ---> punct ---> None
# Teaching ---> csubj ---> None
# children ---> dobj ---> None
# about ---> prep ---> None
# where ---> advmod ---> None
# their ---> poss ---> None
# food ---> nsubj ---> None
# is ---> pcomp ---> None
# from ---> prep ---> None
# is ---> ROOT ---> None
# also ---> advmod ---> None
# brilliant ---> acomp ---> None
# . ---> punct ---> None
#
#  ---> ROOT ---> None
# A ---> det ---> None
# study ---> nsubj ---> None
# carried ---> acl ---> None
# out ---> prt ---> None
# in ---> prep ---> None
# the ---> det ---> None
# Netherlands ---> pobj ---> None
# found ---> ROOT ---> None
# that ---> mark ---> None
# children ---> nsubj ---> None
# who ---> nsubj ---> None
# watched ---> relcl ---> None
# television ---> compound ---> None
# programmes ---> dobj ---> None
# with ---> prep ---> None
# healthy ---> amod ---> None
# foods ---> pobj ---> None
# were ---> ccomp ---> None
# more ---> advmod ---> None
# likely ---> acomp ---> None
# to ---> aux ---> None
# choose ---> xcomp ---> None
# healthy ---> amod ---> None
# options ---> dobj ---> None
# for ---> prep ---> None
# snacks ---> pobj ---> None
# . ---> punct ---> None
# Waffles ---> nsubj ---> None
# and ---> cc ---> None
# Mochi ---> conj ---> None
# is ---> ROOT ---> None
# an ---> det ---> None
# excellent ---> amod ---> None
# platform ---> attr ---> None
# , ---> punct ---> None
# widely ---> advmod ---> None
# available ---> amod ---> None
# across ---> prep ---> None
# the ---> det ---> None
# world ---> pobj ---> None
# , ---> punct ---> None
# which ---> nsubj ---> None
# could ---> aux ---> None
# educate ---> relcl ---> None
# children ---> dobj ---> None
# about ---> prep ---> None
# what ---> pobj ---> None
# foods ---> nsubj ---> None
# are ---> pcomp ---> None
# good ---> acomp ---> None
# and ---> cc ---> None
# what ---> attr ---> None
# their ---> poss ---> None
# health ---> compound ---> None
# benefits ---> nsubj ---> None
# are ---> conj ---> None
# , ---> punct ---> None
# alongside ---> prep ---> None
# where ---> pobj ---> None
# they ---> nsubj ---> None
# come ---> pcomp ---> None
# from ---> prep ---> None
# . ---> punct ---> None
#
#  ---> ROOT ---> None
# Children ---> nsubj ---> None
# are ---> aux ---> None
# still ---> advmod ---> None
# eating ---> ROOT ---> None
# too ---> advmod ---> None
# many ---> amod ---> None
# calories ---> dobj ---> None
# , ---> punct ---> None
# including ---> prep ---> None
# sugar ---> pobj ---> None
# , ---> punct ---> None
# and ---> cc ---> None
# often ---> advmod ---> None
# the ---> det ---> None
# wrong ---> amod ---> None
# foods ---> conj ---> None
# and ---> cc ---> None
# so ---> conj ---> None
# parents ---> nsubj ---> None
# need ---> conj ---> None
# to ---> aux ---> None
# be ---> auxpass ---> None
# provided ---> xcomp ---> None
# with ---> prep ---> None
# the ---> det ---> None
# correct ---> amod ---> None
# knowledge ---> pobj ---> None
# and ---> cc ---> None
# information ---> conj ---> None
# to ---> aux ---> None
# support ---> advcl ---> None
# their ---> poss ---> None
# child ---> poss ---> None
# ’s ---> case ---> None
# health ---> dobj ---> None
# and ---> cc ---> None
# wellbeing ---> conj ---> None
# . ---> punct ---> None

# %% [markdown]
# ## Lemmatization

# %%
for token in doc:
    print(token.text, '--->', token.lemma_, '--->', spacy.explain(token.lemma))
# Out:
# The ---> the ---> None
# idea ---> idea ---> None
# is ---> be ---> None
# to ---> to ---> None
# show ---> show ---> None
# children ---> child ---> None
# where ---> where ---> None
# food ---> food ---> None
# comes ---> come ---> None
# from ---> from ---> None
# and ---> and ---> None
# some ---> some ---> None
# ways ---> way ---> None
# of ---> of ---> None
# cooking ---> cook ---> None
# it ---> it ---> None
# from ---> from ---> None
# scratch ---> scratch ---> None
# – ---> – ---> None
# instead ---> instead ---> None
# of ---> of ---> None
# just ---> just ---> None
# buying ---> buy ---> None
# pre ---> pre ---> None
# - ---> - ---> None
# made ---> make ---> None
# meals ---> meal ---> None
# from ---> from ---> None
# the ---> the ---> None
# supermarket ---> supermarket ---> None
# . ---> . ---> None
# How ---> how ---> None
# a ---> a ---> None
# child ---> child ---> None
# eats ---> eat ---> None
# can ---> can ---> None
# have ---> have ---> None
# a ---> a ---> None
# serious ---> serious ---> None
# impact ---> impact ---> None
# on ---> on ---> None
# their ---> their ---> None
# overall ---> overall ---> None
# health ---> health ---> None
# and ---> and ---> None
# wellbeing ---> wellbee ---> None
# throughout ---> throughout ---> None
# life ---> life ---> None
# . ---> . ---> None
#
#  --->
#  ---> None
# Leading ---> lead ---> None
# by ---> by ---> None
# example ---> example ---> None
# , ---> , ---> None
# like ---> like ---> None
# Mochi ---> Mochi ---> None
# and ---> and ---> None
# Waffles ---> Waffles ---> None
# , ---> , ---> None
# is ---> be ---> None
# a ---> a ---> None
# great ---> great ---> None
# way ---> way ---> None
# to ---> to ---> None
# do ---> do ---> None
# this ---> this ---> None
# . ---> . ---> None
# Teaching ---> teach ---> None
# children ---> child ---> None
# about ---> about ---> None
# where ---> where ---> None
# their ---> their ---> None
# food ---> food ---> None
# is ---> be ---> None
# from ---> from ---> None
# is ---> be ---> None
# also ---> also ---> None
# brilliant ---> brilliant ---> None
# . ---> . ---> None
#
#  --->
#  ---> None
# A ---> a ---> None
# study ---> study ---> None
# carried ---> carry ---> None
# out ---> out ---> None
# in ---> in ---> None
# the ---> the ---> None
# Netherlands ---> Netherlands ---> None
# found ---> find ---> None
# that ---> that ---> None
# children ---> child ---> None
# who ---> who ---> None
# watched ---> watch ---> None
# television ---> television ---> None
# programmes ---> programme ---> None
# with ---> with ---> None
# healthy ---> healthy ---> None
# foods ---> food ---> None
# were ---> be ---> None
# more ---> more ---> None
# likely ---> likely ---> None
# to ---> to ---> None
# choose ---> choose ---> None
# healthy ---> healthy ---> None
# options ---> option ---> None
# for ---> for ---> None
# snacks ---> snack ---> None
# . ---> . ---> None
# Waffles ---> Waffles ---> None
# and ---> and ---> None
# Mochi ---> Mochi ---> None
# is ---> be ---> None
# an ---> an ---> None
# excellent ---> excellent ---> None
# platform ---> platform ---> None
# , ---> , ---> None
# widely ---> widely ---> None
# available ---> available ---> None
# across ---> across ---> None
# the ---> the ---> None
# world ---> world ---> None
# , ---> , ---> None
# which ---> which ---> None
# could ---> could ---> None
# educate ---> educate ---> None
# children ---> child ---> None
# about ---> about ---> None
# what ---> what ---> None
# foods ---> food ---> None
# are ---> be ---> None
# good ---> good ---> None
# and ---> and ---> None
# what ---> what ---> None
# their ---> their ---> None
# health ---> health ---> None
# benefits ---> benefit ---> None
# are ---> be ---> None
# , ---> , ---> None
# alongside ---> alongside ---> None
# where ---> where ---> None
# they ---> they ---> None
# come ---> come ---> None
# from ---> from ---> None
# . ---> . ---> None
#
#  --->
#  ---> None
# Children ---> child ---> None
# are ---> be ---> None
# still ---> still ---> None
# eating ---> eat ---> None
# too ---> too ---> None
# many ---> many ---> None
# calories ---> calorie ---> None
# , ---> , ---> None
# including ---> include ---> None
# sugar ---> sugar ---> None
# , ---> , ---> None
# and ---> and ---> None
# often ---> often ---> None
# the ---> the ---> None
# wrong ---> wrong ---> None
# foods ---> food ---> None
# and ---> and ---> None
# so ---> so ---> None
# parents ---> parent ---> None
# need ---> need ---> None
# to ---> to ---> None
# be ---> be ---> None
# provided ---> provide ---> None
# with ---> with ---> None
# the ---> the ---> None
# correct ---> correct ---> None
# knowledge ---> knowledge ---> None
# and ---> and ---> None
# information ---> information ---> None
# to ---> to ---> None
# support ---> support ---> None
# their ---> their ---> None
# child ---> child ---> None
# ’s ---> ’s ---> None
# health ---> health ---> None
# and ---> and ---> None
# wellbeing ---> wellbeing ---> None
# . ---> . ---> None

# %% [markdown]
# ## Sentence Boundary Detection

# %%
list(doc.sents)
# Out:
# [The idea is to show children where food comes from and some ways of cooking it from scratch – instead of just buying pre-made meals from the supermarket.,
#  How a child eats can have a serious impact on their overall health and wellbeing throughout life.,
#  Leading by example, like Mochi and Waffles, is a great way to do this.,
#  Teaching children about where their food is from is also brilliant.,
#  ,
#  A study carried out in the Netherlands found that children who watched television programmes with healthy foods were more likely to choose healthy options for snacks.,
#  Waffles and Mochi is an excellent platform, widely available across the world, which could educate children about what foods are good and what their health benefits are, alongside where they come from.,
#  ,
#  Children are still eating too many calories, including sugar, and often the wrong foods and so parents need to be provided with the correct knowledge and information to support their child’s health and wellbeing.]

# %%
sentences = list(doc.sents)

# %%
for sentence in sentences:
    print(sentence)
# Out:
# The idea is to show children where food comes from and some ways of cooking it from scratch – instead of just buying pre-made meals from the supermarket.
# How a child eats can have a serious impact on their overall health and wellbeing throughout life.
#
# Leading by example, like Mochi and Waffles, is a great way to do this.
# Teaching children about where their food is from is also brilliant.
#
#
# A study carried out in the Netherlands found that children who watched television programmes with healthy foods were more likely to choose healthy options for snacks.
# Waffles and Mochi is an excellent platform, widely available across the world, which could educate children about what foods are good and what their health benefits are, alongside where they come from.
#
#
# Children are still eating too many calories, including sugar, and often the wrong foods and so parents need to be provided with the correct knowledge and information to support their child’s health and wellbeing.

# %% [markdown]
# ## Named Entity

# %%
for ent in doc.ents:
    print(ent.text, '---->', ent.label, '---->', spacy.explain(ent.label))
# Out:
# Mochi ----> 384 ----> None
# Netherlands ----> 384 ----> None
# Mochi ----> 383 ----> None

# %% [markdown]
# ## Visualization

# %%
from spacy import displacy

# %%
displacy.render(doc, style='ent', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">The idea is to show children where food comes from and some ways of cooking it from scratch – instead of just buying pre-made meals from the supermarket.How a child eats can have a serious impact on their overall health and wellbeing throughout life.</br>Leading by example, like
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Mochi
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  and Waffles, is a great way to do this.Teaching children about where their food is from is also brilliant.</br>A study carried out in the
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Netherlands
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  found that children who watched television programmes with healthy foods were more likely to choose healthy options for snacks.Waffles and
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Mochi
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  is an excellent platform, widely available across the world, which could educate children about what foods are good and what their health benefits are, alongside where they come from.</br>Children are still eating too many calories, including sugar, and often the wrong foods and so parents need to be provided with the correct knowledge and information to support their child’s health and wellbeing.</div></span>

# %%
displacy.render(doc, style='dep', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="af50b8b3d86d4a11b4815ae621ad7b62-0" class="displacy" width="29100" height="1274.5" direction="ltr" style="max-width: none; height: 1274.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1184.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">The</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1184.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">idea</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1184.5">
#     <tspan class="displacy-word" fill="currentColor" x="400">is</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1184.5">
#     <tspan class="displacy-word" fill="currentColor" x="575">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1184.5">
#     <tspan class="displacy-word" fill="currentColor" x="750">show</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1184.5">
#     <tspan class="displacy-word" fill="currentColor" x="925">children</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1184.5">
#     <tspan class="displacy-word" fill="currentColor" x="1100">where</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1184.5">
#     <tspan class="displacy-word" fill="currentColor" x="1275">food</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1184.5">
#     <tspan class="displacy-word" fill="currentColor" x="1450">comes</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1184.5">
#     <tspan class="displacy-word" fill="currentColor" x="1625">from</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1184.5">
#     <tspan class="displacy-word" fill="currentColor" x="1800">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1184.5">
#     <tspan class="displacy-word" fill="currentColor" x="1975">some</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1184.5">
#     <tspan class="displacy-word" fill="currentColor" x="2150">ways</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1184.5">
#     <tspan class="displacy-word" fill="currentColor" x="2325">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1184.5">
#     <tspan class="displacy-word" fill="currentColor" x="2500">cooking</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2500">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1184.5">
#     <tspan class="displacy-word" fill="currentColor" x="2675">it</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2675">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1184.5">
#     <tspan class="displacy-word" fill="currentColor" x="2850">from</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1184.5">
#     <tspan class="displacy-word" fill="currentColor" x="3025">scratch –</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3025">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1184.5">
#     <tspan class="displacy-word" fill="currentColor" x="3200">instead</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1184.5">
#     <tspan class="displacy-word" fill="currentColor" x="3375">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3375">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1184.5">
#     <tspan class="displacy-word" fill="currentColor" x="3550">just</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3550">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1184.5">
#     <tspan class="displacy-word" fill="currentColor" x="3725">buying</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3725">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1184.5">
#     <tspan class="displacy-word" fill="currentColor" x="3900">pre-</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3900">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1184.5">
#     <tspan class="displacy-word" fill="currentColor" x="4075">made</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4075">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1184.5">
#     <tspan class="displacy-word" fill="currentColor" x="4250">meals</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4250">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1184.5">
#     <tspan class="displacy-word" fill="currentColor" x="4425">from</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4425">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1184.5">
#     <tspan class="displacy-word" fill="currentColor" x="4600">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4600">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1184.5">
#     <tspan class="displacy-word" fill="currentColor" x="4775">supermarket.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4775">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1184.5">
#     <tspan class="displacy-word" fill="currentColor" x="4950">How</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4950">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1184.5">
#     <tspan class="displacy-word" fill="currentColor" x="5125">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="5125">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1184.5">
#     <tspan class="displacy-word" fill="currentColor" x="5300">child</tspan>
#     <tspan class="displacy-tag" dy="2em" fil

# %% [markdown]
# ## Putting it all together

# %%
lis = []

# %%
for token in doc:
    dic = {}
    dic['Token'] = token.text
    dic['POS'] = token.pos_
    dic['Tags'] = token.tag_
    dic['Dep'] = token.dep_
    dic['Explanation'] = spacy.explain(token.tag_)
    lis.append(dic)

# %%
import pandas as pd

# %%
data = pd.DataFrame(lis)

# %%
data
# Out:
#          Token    POS Tags    Dep                        Explanation
# 0          The    DET   DT    det                         determiner
# 1         idea   NOUN   NN  nsubj             noun, singular or mass
# 2           is    AUX  VBZ   ROOT  verb, 3rd person singular present
# 3           to   PART   TO    aux                   infinitival "to"
# 4         show   VERB   VB  xcomp                    verb, base form
# ..         ...    ...  ...    ...                                ...
# 177         ’s   PART  POS   case                  possessive ending
# 178     health   NOUN   NN   dobj             noun, singular or mass
# 179        and  CCONJ   CC     cc          conjunction, coordinating
# 180  wellbeing   NOUN   NN   conj             noun, singular or mass
# 181          .  PUNCT    .  punct  punctuation mark, sentence closer
#
# [182 rows x 5 columns]

# %% [markdown]
# #### You can reindex if you do not like the arrangement

# %%
l = []
for ent in doc.ents:
    d = {}
    d['entities'] = ent.text
    d['labels'] = ent.label_
    d['Explanation'] = spacy.explain(ent.label_)
    l.append(d)

# %%
entities = pd.DataFrame(l)

# %%
entities
# Out:
#       entities labels                              Explanation
# 0        Mochi    GPE                Countries, cities, states
# 1  Netherlands    GPE                Countries, cities, states
# 2        Mochi    ORG  Companies, agencies, institutions, etc.

# %%
entities.to_csv('NLPTasks', index = False)

# %% [markdown]
# # Website 2 Scraping and Summarization

# %%
import requests
from bs4 import BeautifulSoup
from gensim.summarization import summarize

# %%
url2 = 'https://theconversation.com/selfish-or-selfless-human-nature-means-youre-both-155528'

# %%
page2 = requests.get(url2).text

# %%
soup2 = BeautifulSoup(page2)

# %%
head2 = soup2.find('h1').get_text()

# %%
p_tags2 = soup2.find_all('p')

# %%
texts2 = [tags.get_text().strip() for tags in p_tags2]

# %%
print(texts2)
# Out:
# ['Postdoctoral Scholar in Social Cognitive Neuroscience, University of Chicago', 'Professor of Psychology, and Psychiatry and Behavioral Neuroscience, University of Chicago', 'The authors do not work for, consult, own shares in or receive funding from any company or organisation that would benefit from this article, and have disclosed no relevant affiliations beyond their academic appointment.', 'The Conversation is funded by the National Research Foundation, eight universities, including the Cape Peninsula University of Technology, Rhodes University, Stellenbosch University and the Universities of Cape Town, Johannesburg, Kwa-Zulu Natal, Pretoria, and South Africa. It is hosted by the Universities of the Witwatersrand and Western Cape, the African Population and Health Research Centre and the Nigerian Academy of Science. The Bill & Melinda Gates Foundation is a Strategic Partner. more', 'Looking out for number one has been important for survival for as long as there have been human beings.', 'But self-interest isn’t the only trait that helped people win at evolution. Groups of individuals who were predisposed to cooperate, care for each other and uphold social norms of fairness tended to survive and expand relative to other groups, thereby allowing these prosocial motivations to proliferate.', 'So today, concern for oneself and concern for others both contribute to our sense of fairness. Together they facilitate cooperation among unrelated individuals, something ubiquitous among people but uncommon in nature.', 'A critical question is how people balance these two motivations when making decisions.', 'We investigate this question in our work at the Social Cognitive Neuroscience Laboratory at the University of Chicago, combining behavioral economics tasks with neuroimaging methods that let us watch what’s happening in the brains of adults and children. We’ve found evidence that people care about both themselves and others – but it’s the self that takes precedence.', 'Children are sensitive to fairness from a very early age.', 'For instance, if you give two siblings different numbers of cookies, the one who receives fewer will likely throw a fit. Very young children, between 3 and 6 years of age, are highly sensitive to concerns about equality. Splitting resources is “fair” if everyone gets the same amount. By 6 years old, children will even throw resources away rather than allocate them unequally.', 'As they grow, children develop abilities to think about the minds of others and care about social norms. Soon, they begin to understand the principle of “equity” – a “fair” distribution can be unequal if it takes into account people’s need, effort or merit. For instance, a sibling who does more chores may be entitled to more cookies. This shift toward equity appears to be universal in humans and follows similar patterns across cultures.', 'Interestingly, it takes several years of development before children’s own behavior catches up with their understanding of fairness – for instance, by opting to share resources more equally rather than prioritizing their own payoffs.', 'To investigate how children’s developing brains guide their understanding of fairness, we invited kids ranging from age 4 to 8 into our lab. We gave them four candies to divide between two other people. After they decided how many (if any) to share, we measured their brain activity using noninvasive electroencephalography while they watched an adult split 10 rewards – like candies, coins or stickers – between two other people. The distributions could be fair (5:5), slightly unfair (7:3) or very unfair (10:0).', 'At first, kids’ brain activity looked the same whether they were observing a slightly unfair or very unfair distribution of the treats. After 400 milliseconds, the brain electrical activity for kids who saw the slightly unfair 7:3 split changed to look like the brain response of kids who saw the completely fair 5:5 division.', 'Our interpretation is that t ...

# %%
sentence_list2 = [sentence for sentence in texts2 if not '\n' in sentence]

# %%
#for sentence in the original document, if it does not contain a new line, return the sentence

# %%
sentence_list2 = [sentence for sentence in sentence_list2 if '.' in sentence]

# %%
sentence_list2
# Out:
# ['The authors do not work for, consult, own shares in or receive funding from any company or organisation that would benefit from this article, and have disclosed no relevant affiliations beyond their academic appointment.',
#  'The Conversation is funded by the National Research Foundation, eight universities, including the Cape Peninsula University of Technology, Rhodes University, Stellenbosch University and the Universities of Cape Town, Johannesburg, Kwa-Zulu Natal, Pretoria, and South Africa. It is hosted by the Universities of the Witwatersrand and Western Cape, the African Population and Health Research Centre and the Nigerian Academy of Science. The Bill & Melinda Gates Foundation is a Strategic Partner. more',
#  'Looking out for number one has been important for survival for as long as there have been human beings.',
#  'But self-interest isn’t the only trait that helped people win at evolution. Groups of individuals who were predisposed to cooperate, care for each other and uphold social norms of fairness tended to survive and expand relative to other groups, thereby allowing these prosocial motivations to proliferate.',
#  'So today, concern for oneself and concern for others both contribute to our sense of fairness. Together they facilitate cooperation among unrelated individuals, something ubiquitous among people but uncommon in nature.',
#  'A critical question is how people balance these two motivations when making decisions.',
#  'We investigate this question in our work at the Social Cognitive Neuroscience Laboratory at the University of Chicago, combining behavioral economics tasks with neuroimaging methods that let us watch what’s happening in the brains of adults and children. We’ve found evidence that people care about both themselves and others – but it’s the self that takes precedence.',
#  'Children are sensitive to fairness from a very early age.',
#  'For instance, if you give two siblings different numbers of cookies, the one who receives fewer will likely throw a fit. Very young children, between 3 and 6 years of age, are highly sensitive to concerns about equality. Splitting resources is “fair” if everyone gets the same amount. By 6 years old, children will even throw resources away rather than allocate them unequally.',
#  'As they grow, children develop abilities to think about the minds of others and care about social norms. Soon, they begin to understand the principle of “equity” – a “fair” distribution can be unequal if it takes into account people’s need, effort or merit. For instance, a sibling who does more chores may be entitled to more cookies. This shift toward equity appears to be universal in humans and follows similar patterns across cultures.',
#  'Interestingly, it takes several years of development before children’s own behavior catches up with their understanding of fairness – for instance, by opting to share resources more equally rather than prioritizing their own payoffs.',
#  'To investigate how children’s developing brains guide their understanding of fairness, we invited kids ranging from age 4 to 8 into our lab. We gave them four candies to divide between two other people. After they decided how many (if any) to share, we measured their brain activity using noninvasive electroencephalography while they watched an adult split 10 rewards – like candies, coins or stickers – between two other people. The distributions could be fair (5:5), slightly unfair (7:3) or very unfair (10:0).',
#  'At first, kids’ brain activity looked the same whether they were observing a slightly unfair or very unfair distribution of the treats. After 400 milliseconds, the brain electrical activity for kids who saw the slightly unfair 7:3 split changed to look like the brain response of kids who saw the completely fair 5:5 division.',
#  'Our interpretation is that the young brains used that short lag time to consider why an adult might have handed out the treats in a slightly unfair way and then resolved that it may actually have been fair.',
#  'Further, children whose brain activity patterns were the most different when viewing fair versus unfair distributions were the most likely to have used merit and need when they originally divided up their candies, before they watched the adults.',
#  'So the EEG recordings indicate that even 4-year-old children expect distributions to be perfectly equal, which makes sense given their natural preference for equality. When children, especially after age 5, watch an adult make a completely unfair distribution, they work to try to understand why this might be the case.',
#  'In your everyday adult life, you face decisions that affect not just yourself, but other people around you. Do you help a stranger pick up their spilled bag and miss your bus? Do you take the big piece of cake and leave the small one for the coworker who is coming later?',
#  'To answer this question, we invited participants to play an economic game. In each round, an anonymous proposer would split US$12 among themselves, the participant and another player. The participant could decide to accept the distribution, allowing all three players to keep the money, or reject the distribution, meaning no one got anything. While participants made their decision, we measured their neural activity using EEG and fMRI. Functional magnetic resonance imaging reveals active areas of the brain by mapping blood flow.',
#  'The proposer was actually a computer that let us manipulate the fairness of the offers. We found that both fairness for self and fairness for the other were important for participants’ decisions, but people were more willing to tolerate offers which were unfair to others if they themselves received an unfair offer.',
#  'Our design also allowed us to ask whether the same regions of the brain are sensitive to self-interest and concern for other. A popular concept in cognitive science is that we are able to understand other people because we use the same parts of our brain to understand our self. The idea is that the brain activates and manages these shared representations depending on the task at hand.',
#  'But in our studies, we found that rather than shared brain areas, distinct brain networks were involved in thinking about fairness for self and other.',
#  'We also used machine learning to test whether by looking at the brain signals we could predict what kind of offer a participant had received. We could reliably decode a signal in multiple brain networks that corresponded to fairness for self – that is, “did I get at least a third of the $12?” And this focus on self-interest dominated the early stages of decision-making.',
#  'Overall, these results suggest that people prioritize their own payoffs first and only later integrate how their options affect other people. So while people do care about others, self-interested behavior is alive and well, even in behavioral economics games. Once people get their fair share, then they are willing to be fair to others. You’re more likely to help the stranger with her bag if you know there will be another bus in 10 minutes, rather than an hour.',
#  '[Get our best science, health and technology stories. Sign up for The Conversation’s science newsletter.]',
#  'In daily life, people are rarely just responders, like in the game in our lab. We are interested in what happens when a person must make decisions that involve other people, such as delegating responsibilities among team members, or when an individual has limited power to personally affect the way resources are divided, as in government spending.',
#  'One implication from our work is that when people want to reach a compromise, it may be important to ensure that no one feels taken advantage of. Human nature seems to be to make sure you’ve taken care of yourself before you consider the needs of others.',
#  'Write an article and join a growing community of more than 127,600 academics and researchers from 4,035 institutions.',
#  'Copyright © 2010–2021, The Conversation Africa, Inc.']

# %%
article2 = ''.join(sentence_list2)

# %%
summary2 = summarize(article2, ratio=0.15)

print('Length of original article: {}'.format(len(article2)))
print('Length of summary: {}\n'.format(len(summary2)))  
print('Headline: {} \n'.format(head2))
print('Article Summary: \n{}'.format(summary2))
# Out:
# Length of original article: 7882
# Length of summary: 2269
#
# Headline:
#
#             Selfish or selfless? Human nature means you’re both
#
#
#
# Article Summary:
# Together they facilitate cooperation among unrelated individuals, something ubiquitous among people but uncommon in nature.A critical question is how people balance these two motivations when making decisions.We investigate this question in our work at the Social Cognitive Neuroscience Laboratory at the University of Chicago, combining behavioral economics tasks with neuroimaging methods that let us watch what’s happening in the brains of adults and children.
# We’ve found evidence that people care about both themselves and others – but it’s the self that takes precedence.Children are sensitive to fairness from a very early age.For instance, if you give two siblings different numbers of cookies, the one who receives fewer will likely throw a fit.
# This shift toward equity appears to be universal in humans and follows similar patterns across cultures.Interestingly, it takes several years of development before children’s own behavior catches up with their understanding of fairness – for instance, by opting to share resources more equally rather than prioritizing their own payoffs.To investigate how children’s developing brains guide their understanding of fairness, we invited kids ranging from age 4 to 8 into our lab.
# After they decided how many (if any) to share, we measured their brain activity using noninvasive electroencephalography while they watched an adult split 10 rewards – like candies, coins or stickers – between two other people.
# After 400 milliseconds, the brain electrical activity for kids who saw the slightly unfair 7:3 split changed to look like the brain response of kids who saw the completely fair 5:5 division.Our interpretation is that the young brains used that short lag time to consider why an adult might have handed out the treats in a slightly unfair way and then resolved that it may actually have been fair.Further, children whose brain activity patterns were the most different when viewing fair versus unfair distributions were the most likely to have used merit and need when they originally divided up their candies, before they watched the adults.So the EEG recordings indicate that even 4-year-old children expect distributions to be perfectly equal, which makes sense given their natural preference for equality.

# %%
import spacy
nlp = spacy.load('en_core_web_sm')

# %%
doc = nlp(summary2)

# %% [markdown]
# ## Tokenization

# %%
for token in doc:
    print(token.text, '--->', spacy.explain(token.text))
# Out:
# Together ---> None
# they ---> None
# facilitate ---> None
# cooperation ---> None
# among ---> None
# unrelated ---> None
# individuals ---> None
# , ---> punctuation mark, comma
# something ---> None
# ubiquitous ---> None
# among ---> None
# people ---> None
# but ---> None
# uncommon ---> None
# in ---> None
# nature ---> None
# . ---> punctuation mark, sentence closer
# A ---> None
# critical ---> None
# question ---> None
# is ---> None
# how ---> None
# people ---> None
# balance ---> None
# these ---> None
# two ---> None
# motivations ---> None
# when ---> None
# making ---> None
# decisions ---> None
# . ---> punctuation mark, sentence closer
# We ---> None
# investigate ---> None
# this ---> None
# question ---> None
# in ---> None
# our ---> None
# work ---> None
# at ---> None
# the ---> None
# Social ---> None
# Cognitive ---> None
# Neuroscience ---> None
# Laboratory ---> None
# at ---> None
# the ---> None
# University ---> None
# of ---> None
# Chicago ---> None
# , ---> punctuation mark, comma
# combining ---> None
# behavioral ---> None
# economics ---> None
# tasks ---> None
# with ---> None
# neuroimaging ---> None
# methods ---> None
# that ---> None
# let ---> None
# us ---> None
# watch ---> None
# what ---> None
# ’s ---> None
# happening ---> None
# in ---> None
# the ---> None
# brains ---> None
# of ---> None
# adults ---> None
# and ---> None
# children ---> None
# . ---> punctuation mark, sentence closer
#
#  ---> None
# We ---> None
# ’ve ---> None
# found ---> None
# evidence ---> None
# that ---> None
# people ---> None
# care ---> None
# about ---> None
# both ---> None
# themselves ---> None
# and ---> None
# others ---> None
# – ---> None
# but ---> None
# it ---> None
# ’s ---> None
# the ---> None
# self ---> None
# that ---> None
# takes ---> None
# precedence ---> None
# . ---> punctuation mark, sentence closer
# Children ---> None
# are ---> None
# sensitive ---> None
# to ---> None
# fairness ---> None
# from ---> None
# a ---> None
# very ---> None
# early ---> None
# age ---> None
# . ---> punctuation mark, sentence closer
# For ---> None
# instance ---> None
# , ---> punctuation mark, comma
# if ---> None
# you ---> None
# give ---> None
# two ---> None
# siblings ---> None
# different ---> None
# numbers ---> None
# of ---> None
# cookies ---> None
# , ---> punctuation mark, comma
# the ---> None
# one ---> None
# who ---> None
# receives ---> None
# fewer ---> None
# will ---> None
# likely ---> None
# throw ---> None
# a ---> None
# fit ---> None
# . ---> punctuation mark, sentence closer
#
#  ---> None
# This ---> None
# shift ---> None
# toward ---> None
# equity ---> None
# appears ---> None
# to ---> None
# be ---> None
# universal ---> None
# in ---> None
# humans ---> None
# and ---> None
# follows ---> None
# similar ---> None
# patterns ---> None
# across ---> None
# cultures ---> None
# . ---> punctuation mark, sentence closer
# Interestingly ---> None
# , ---> punctuation mark, comma
# it ---> None
# takes ---> None
# several ---> None
# years ---> None
# of ---> None
# development ---> None
# before ---> None
# children ---> None
# ’s ---> None
# own ---> None
# behavior ---> None
# catches ---> None
# up ---> None
# with ---> None
# their ---> None
# understanding ---> None
# of ---> None
# fairness ---> None
# – ---> None
# for ---> None
# instance ---> None
# , ---> punctuation mark, comma
# by ---> None
# opting ---> None
# to ---> None
# share ---> None
# resources ---> None
# more ---> None
# equally ---> None
# rather ---> None
# than ---> None
# prioritizing ---> None
# their ---> None
# own ---> None
# payoffs ---> None
# . ---> punctuation mark, sentence closer
# To ---> None
# investigate ---> None
# how ---> None
# children ---> None
# ’s ---> None
# developing ---> None
# brains ---> None
# guide ---> None
# their ---> None
# understanding ---> None
# of ---> None
# fairness ---> None
# , ---> punctuation mark, comma
# we ---> None
# invited ---> None
# kids ---> None
# ranging ---> None
# from ---> None
# age ---> None
# 4 ---> None
# to ---> None
# 8 ---> None
# into ---> None
# our ---> None
# lab ---> None
# . ---> punctuation mark, sentence closer
#
#  ---> None
# After ---> None
# they ---> None
# decided ---> None
# how ---> None
# many ---> None
# ( ---> None
# if ---> None
# any ---> None
# ) ---> None
# to ---> None
# share ---> None
# , ---> punctuation mark, comma
# we ---> None
# measured ---> None
# their ---> None
# brain ---> None
# activity ---> None
# using ---> None
# noninvasive ---> None
# electroencephalography ---> None
# while ---> None
# they ---> None
# watched ---> None
# an ---> None
# adult ---> None
# split ---> None
# 10 ---> None
# rewards ---> None
# – ---> None
# like ---> None
# candies ---> None
# , ---> punctuation mark, comma
# coins ---> None
# or ---> None
# stickers ---> None
# – ---> None
# between ---> None
# two ---> None
# other ---> None
# people ---> None
# . ---> punctuation mark, sentence closer
#
#  ---> None
# After ---> None
# 400 ---> None
# milliseconds ---> None
# , ---> punctuation mark, comma
# the ---> None
# brain ---> None
# electrical ---> None
# activity ---> None
# for ---> None
# kids ---> None
# who ---> None
# saw ---> None
# the ---> None
# slightly ---> None
# unfair ---> None
# 7:3 ---> None
# split ---> None
# changed ---> None
# to ---> None
# look ---> None
# like ---> None
# the ---> None
# brain ---> None
# response ---> None
# of ---> None
# kids ---> None
# who ---> None
# saw ---> None
# the ---> None
# completely ---> None
# fair ---> None
# 5:5 ---> None
# division ---> None
# . ---> punctuation mark, sentence closer
# Our ---> None
# interpretation ---> None
# is ---> None
# that ---> None
# the ---> None
# young ---> None
# brains ---> None
# used ---> None
# that ---> None
# short ---> None
# lag ---> None
# time ---> None
# to ---> None
# consider ---> None
# why ---> None
# an ---> None
# adult ---> None
# might ---> None
# have ---> None
# handed ---> None
# out ---> None
# the ---> None
# treats ---> None
# in ---> None
# a ---> None
# slightly ---> None
# unfair ---> None
# way ---> None
# and ---> None
# then ---> None
# resolved ---> None
# that ---> None
# it ---> None
# may ---> None
# actually ---> None
# have ---> None
# been ---> None
# fair ---> None
# . ---> punctuation mark, sentence closer
# Further ---> None
# , ---> punctuation mark, comma
# children ---> None
# whose ---> None
# brain ---> None
# activity ---> None
# patterns ---> None
# were ---> None
# the ---> None
# most ---> None
# different ---> None
# when ---> None
# viewing ---> None
# fair ---> None
# versus ---> None
# unfair ---> None
# distributions ---> None
# were ---> None
# the ---> None
# most ---> None
# likely ---> None
# to ---> None
# have ---> None
# used ---> None
# merit ---> None
# and ---> None
# need ---> None
# when ---> None
# they ---> None
# originally ---> None
# divided ---> None
# up ---> None
# their ---> None
# candies ---> None
# , ---> punctuation mark, comma
# before ---> None
# they ---> None
# watched ---> None
# the ---> None
# adults ---> None
# . ---> punctuation mark, sentence closer
# So ---> None
# the ---> None
# EEG ---> None
# recordings ---> None
# indicate ---> None
# that ---> None
# even ---> None
# 4 ---> None
# - ---> None
# year ---> None
# - ---> None
# old ---> None
# children ---> None
# expect ---> None
# distributions ---> None
# to ---> None
# be ---> None
# perfectly ---> None
# equal ---> None
# , ---> punctuation mark, comma
# which ---> None
# makes ---> None
# sense ---> None
# given ---> None
# their ---> None
# natural ---> None
# preference ---> None
# for ---> None
# equality ---> None
# . ---> punctuation mark, sentence closer

# %% [markdown]
# ## Dependency Parsing

# %%
for token in doc:
    print(token.text, '--->', token.dep_, '--->', spacy.explain(token.dep))
# Out:
# Together ---> advmod ---> None
# they ---> nsubj ---> None
# facilitate ---> ROOT ---> None
# cooperation ---> dobj ---> None
# among ---> prep ---> None
# unrelated ---> amod ---> None
# individuals ---> pobj ---> None
# , ---> punct ---> None
# something ---> dobj ---> None
# ubiquitous ---> amod ---> None
# among ---> prep ---> None
# people ---> pobj ---> None
# but ---> cc ---> None
# uncommon ---> conj ---> None
# in ---> prep ---> None
# nature ---> pobj ---> None
# . ---> punct ---> None
# A ---> det ---> None
# critical ---> amod ---> None
# question ---> nsubj ---> None
# is ---> ROOT ---> None
# how ---> advmod ---> None
# people ---> nsubj ---> None
# balance ---> ccomp ---> None
# these ---> det ---> None
# two ---> nummod ---> None
# motivations ---> dobj ---> None
# when ---> advmod ---> None
# making ---> advcl ---> None
# decisions ---> dobj ---> None
# . ---> punct ---> None
# We ---> nsubj ---> None
# investigate ---> ROOT ---> None
# this ---> det ---> None
# question ---> dobj ---> None
# in ---> prep ---> None
# our ---> poss ---> None
# work ---> pobj ---> None
# at ---> prep ---> None
# the ---> det ---> None
# Social ---> compound ---> None
# Cognitive ---> compound ---> None
# Neuroscience ---> compound ---> None
# Laboratory ---> pobj ---> None
# at ---> prep ---> None
# the ---> det ---> None
# University ---> pobj ---> None
# of ---> prep ---> None
# Chicago ---> pobj ---> None
# , ---> punct ---> None
# combining ---> advcl ---> None
# behavioral ---> amod ---> None
# economics ---> compound ---> None
# tasks ---> dobj ---> None
# with ---> prep ---> None
# neuroimaging ---> amod ---> None
# methods ---> pobj ---> None
# that ---> nsubj ---> None
# let ---> relcl ---> None
# us ---> nsubj ---> None
# watch ---> ccomp ---> None
# what ---> nsubj ---> None
# ’s ---> aux ---> None
# happening ---> ccomp ---> None
# in ---> prep ---> None
# the ---> det ---> None
# brains ---> pobj ---> None
# of ---> prep ---> None
# adults ---> pobj ---> None
# and ---> cc ---> None
# children ---> conj ---> None
# . ---> punct ---> None
#
#  ---> ROOT ---> None
# We ---> nsubj ---> None
# ’ve ---> aux ---> None
# found ---> ROOT ---> None
# evidence ---> dobj ---> None
# that ---> mark ---> None
# people ---> nsubj ---> None
# care ---> acl ---> None
# about ---> prep ---> None
# both ---> preconj ---> None
# themselves ---> pobj ---> None
# and ---> cc ---> None
# others ---> conj ---> None
# – ---> punct ---> None
# but ---> cc ---> None
# it ---> nsubj ---> None
# ’s ---> conj ---> None
# the ---> det ---> None
# self ---> attr ---> None
# that ---> nsubj ---> None
# takes ---> relcl ---> None
# precedence ---> dobj ---> None
# . ---> punct ---> None
# Children ---> nsubj ---> None
# are ---> ROOT ---> None
# sensitive ---> acomp ---> None
# to ---> prep ---> None
# fairness ---> pobj ---> None
# from ---> prep ---> None
# a ---> det ---> None
# very ---> advmod ---> None
# early ---> amod ---> None
# age ---> pobj ---> None
# . ---> punct ---> None
# For ---> prep ---> None
# instance ---> pobj ---> None
# , ---> punct ---> None
# if ---> mark ---> None
# you ---> nsubj ---> None
# give ---> advcl ---> None
# two ---> nummod ---> None
# siblings ---> dative ---> None
# different ---> amod ---> None
# numbers ---> dobj ---> None
# of ---> prep ---> None
# cookies ---> pobj ---> None
# , ---> punct ---> None
# the ---> det ---> None
# one ---> appos ---> None
# who ---> nsubj ---> None
# receives ---> relcl ---> None
# fewer ---> dobj ---> None
# will ---> aux ---> None
# likely ---> advmod ---> None
# throw ---> ROOT ---> None
# a ---> det ---> None
# fit ---> dobj ---> None
# . ---> punct ---> None
#
#  ---> ROOT ---> None
# This ---> det ---> None
# shift ---> nsubj ---> None
# toward ---> prep ---> None
# equity ---> pobj ---> None
# appears ---> ROOT ---> None
# to ---> aux ---> None
# be ---> xcomp ---> None
# universal ---> acomp ---> None
# in ---> prep ---> None
# humans ---> pobj ---> None
# and ---> cc ---> None
# follows ---> conj ---> None
# similar ---> amod ---> None
# patterns ---> dobj ---> None
# across ---> prep ---> None
# cultures ---> pobj ---> None
# . ---> punct ---> None
# Interestingly ---> advmod ---> None
# , ---> punct ---> None
# it ---> nsubj ---> None
# takes ---> ROOT ---> None
# several ---> amod ---> None
# years ---> dobj ---> None
# of ---> prep ---> None
# development ---> pobj ---> None
# before ---> mark ---> None
# children ---> poss ---> None
# ’s ---> case ---> None
# own ---> amod ---> None
# behavior ---> nsubj ---> None
# catches ---> advcl ---> None
# up ---> prt ---> None
# with ---> prep ---> None
# their ---> poss ---> None
# understanding ---> pobj ---> None
# of ---> prep ---> None
# fairness ---> pobj ---> None
# – ---> punct ---> None
# for ---> prep ---> None
# instance ---> pobj ---> None
# , ---> punct ---> None
# by ---> prep ---> None
# opting ---> pcomp ---> None
# to ---> aux ---> None
# share ---> xcomp ---> None
# resources ---> dobj ---> None
# more ---> advmod ---> None
# equally ---> advmod ---> None
# rather ---> advmod ---> None
# than ---> prep ---> None
# prioritizing ---> pcomp ---> None
# their ---> poss ---> None
# own ---> amod ---> None
# payoffs ---> dobj ---> None
# . ---> punct ---> None
# To ---> aux ---> None
# investigate ---> advcl ---> None
# how ---> advmod ---> None
# children ---> poss ---> None
# ’s ---> case ---> None
# developing ---> amod ---> None
# brains ---> nsubj ---> None
# guide ---> ccomp ---> None
# their ---> poss ---> None
# understanding ---> dobj ---> None
# of ---> prep ---> None
# fairness ---> pobj ---> None
# , ---> punct ---> None
# we ---> nsubj ---> None
# invited ---> ROOT ---> None
# kids ---> dobj ---> None
# ranging ---> acl ---> None
# from ---> prep ---> None
# age ---> pobj ---> None
# 4 ---> nummod ---> None
# to ---> prep ---> None
# 8 ---> pobj ---> None
# into ---> prep ---> None
# our ---> poss ---> None
# lab ---> pobj ---> None
# . ---> punct ---> None
#
#  ---> ROOT ---> None
# After ---> mark ---> None
# they ---> nsubj ---> None
# decided ---> advcl ---> None
# how ---> advmod ---> None
# many ---> amod ---> None
# ( ---> punct ---> None
# if ---> mark ---> None
# any ---> ccomp ---> None
# ) ---> punct ---> None
# to ---> aux ---> None
# share ---> ccomp ---> None
# , ---> punct ---> None
# we ---> nsubj ---> None
# measured ---> ROOT ---> None
# their ---> poss ---> None
# brain ---> compound ---> None
# activity ---> dobj ---> None
# using ---> advcl ---> None
# noninvasive ---> amod ---> None
# electroencephalography ---> dobj ---> None
# while ---> mark ---> None
# they ---> nsubj ---> None
# watched ---> advcl ---> None
# an ---> det ---> None
# adult ---> compound ---> None
# split ---> dobj ---> None
# 10 ---> nummod ---> None
# rewards ---> relcl ---> None
# – ---> punct ---> None
# like ---> prep ---> None
# candies ---> pobj ---> None
# , ---> punct ---> None
# coins ---> conj ---> None
# or ---> cc ---> None
# stickers ---> conj ---> None
# – ---> punct ---> None
# between ---> prep ---> None
# two ---> nummod ---> None
# other ---> amod ---> None
# people ---> pobj ---> None
# . ---> punct ---> None
#
#  ---> ROOT ---> None
# After ---> prep ---> None
# 400 ---> nummod ---> None
# milliseconds ---> pobj ---> None
# , ---> punct ---> None
# the ---> det ---> None
# brain ---> nmod ---> None
# electrical ---> amod ---> None
# activity ---> nsubj ---> None
# for ---> prep ---> None
# kids ---> pobj ---> None
# who ---> nsubj ---> None
# saw ---> relcl ---> None
# the ---> det ---> None
# slightly ---> advmod ---> None
# unfair ---> amod ---> None
# 7:3 ---> nummod ---> None
# split ---> dobj ---> None
# changed ---> ROOT ---> None
# to ---> aux ---> None
# look ---> advcl ---> None
# like ---> prep ---> None
# the ---> det ---> None
# brain ---> compound ---> None
# response ---> pobj ---> None
# of ---> prep ---> None
# kids ---> pobj ---> None
# who ---> nsubj ---> None
# saw ---> relcl ---> None
# the ---> det ---> None
# completely ---> advmod ---> None
# fair ---> amod ---> None
# 5:5 ---> nummod ---> None
# division ---> dobj ---> None
# . ---> punct ---> None
# Our ---> poss ---> None
# interpretation ---> nsubj ---> None
# is ---> ROOT ---> None
# that ---> mark ---> None
# the ---> det ---> None
# young ---> amod ---> None
# brains ---> nsubj ---> None
# used ---> ccomp ---> None
# that ---> det ---> None
# short ---> amod ---> None
# lag ---> compound ---> None
# time ---> dobj ---> None
# to ---> aux ---> None
# consider ---> relcl ---> None
# why ---> advmod ---> None
# an ---> det ---> None
# adult ---> nsubj ---> None
# might ---> aux ---> None
# have ---> aux ---> None
# handed ---> ccomp ---> None
# out ---> prt ---> None
# the ---> det ---> None
# treats ---> dobj ---> None
# in ---> prep ---> None
# a ---> det ---> None
# slightly ---> advmod ---> None
# unfair ---> amod ---> None
# way ---> pobj ---> None
# and ---> cc ---> None
# then ---> advmod ---> None
# resolved ---> conj ---> None
# that ---> mark ---> None
# it ---> nsubj ---> None
# may ---> aux ---> None
# actually ---> advmod ---> None
# have ---> aux ---> None
# been ---> ccomp ---> None
# fair ---> acomp ---> None
# . ---> punct ---> None
# Further ---> advmod ---> None
# , ---> punct ---> None
# children ---> nsubj ---> None
# whose ---> poss ---> None
# brain ---> compound ---> None
# activity ---> compound ---> None
# patterns ---> nsubj ---> None
# were ---> ROOT ---> None
# the ---> det ---> None
# most ---> advmod ---> None
# different ---> acomp ---> None
# when ---> advmod ---> None
# viewing ---> advcl ---> None
# fair ---> amod ---> None
# versus ---> advmod ---> None
# unfair ---> amod ---> None
# distributions ---> dobj ---> None
# were ---> ccomp ---> None
# the ---> det ---> None
# most ---> advmod ---> None
# likely ---> acomp ---> None
# to ---> aux ---> None
# have ---> aux ---> None
# used ---> xcomp ---> None
# merit ---> dobj ---> None
# and ---> cc ---> None
# need ---> conj ---> None
# when ---> advmod ---> None
# they ---> nsubj ---> None
# originally ---> advmod ---> None
# divided ---> advcl ---> None
# up ---> prt ---> None
# their ---> poss ---> None
# candies ---> dobj ---> None
# , ---> punct ---> None
# before ---> mark ---> None
# they ---> nsubj ---> None
# watched ---> advcl ---> None
# the ---> det ---> None
# adults ---> dobj ---> None
# . ---> punct ---> None
# So ---> advmod ---> None
# the ---> det ---> None
# EEG ---> compound ---> None
# recordings ---> nsubj ---> None
# indicate ---> ROOT ---> None
# that ---> mark ---> None
# even ---> advmod ---> None
# 4 ---> nummod ---> None
# - ---> punct ---> None
# year ---> npadvmod ---> None
# - ---> punct ---> None
# old ---> amod ---> None
# children ---> nsubj ---> None
# expect ---> ccomp ---> None
# distributions ---> nsubj ---> None
# to ---> aux ---> None
# be ---> ccomp ---> None
# perfectly ---> advmod ---> None
# equal ---> acomp ---> None
# , ---> punct ---> None
# which ---> nsubj ---> None
# makes ---> advcl ---> None
# sense ---> dobj ---> None
# given ---> prep ---> None
# their ---> poss ---> None
# natural ---> amod ---> None
# preference ---> pobj ---> None
# for ---> prep ---> None
# equality ---> pobj ---> None
# . ---> punct ---> None

# %% [markdown]
# ## Lemmatization

# %%
for token in doc:
    print(token.text, '--->', token.lemma_, '--->', spacy.explain(token.lemma))
# Out:
# Together ---> together ---> None
# they ---> they ---> None
# facilitate ---> facilitate ---> None
# cooperation ---> cooperation ---> None
# among ---> among ---> None
# unrelated ---> unrelated ---> None
# individuals ---> individual ---> None
# , ---> , ---> None
# something ---> something ---> None
# ubiquitous ---> ubiquitous ---> None
# among ---> among ---> None
# people ---> people ---> None
# but ---> but ---> None
# uncommon ---> uncommon ---> None
# in ---> in ---> None
# nature ---> nature ---> None
# . ---> . ---> None
# A ---> a ---> None
# critical ---> critical ---> None
# question ---> question ---> None
# is ---> be ---> None
# how ---> how ---> None
# people ---> people ---> None
# balance ---> balance ---> None
# these ---> these ---> None
# two ---> two ---> None
# motivations ---> motivation ---> None
# when ---> when ---> None
# making ---> make ---> None
# decisions ---> decision ---> None
# . ---> . ---> None
# We ---> we ---> None
# investigate ---> investigate ---> None
# this ---> this ---> None
# question ---> question ---> None
# in ---> in ---> None
# our ---> our ---> None
# work ---> work ---> None
# at ---> at ---> None
# the ---> the ---> None
# Social ---> Social ---> None
# Cognitive ---> Cognitive ---> None
# Neuroscience ---> Neuroscience ---> None
# Laboratory ---> Laboratory ---> None
# at ---> at ---> None
# the ---> the ---> None
# University ---> University ---> None
# of ---> of ---> None
# Chicago ---> Chicago ---> None
# , ---> , ---> None
# combining ---> combine ---> None
# behavioral ---> behavioral ---> None
# economics ---> economic ---> None
# tasks ---> task ---> None
# with ---> with ---> None
# neuroimaging ---> neuroimaging ---> None
# methods ---> method ---> None
# that ---> that ---> None
# let ---> let ---> None
# us ---> we ---> None
# watch ---> watch ---> None
# what ---> what ---> None
# ’s ---> ’s ---> None
# happening ---> happen ---> None
# in ---> in ---> None
# the ---> the ---> None
# brains ---> brain ---> None
# of ---> of ---> None
# adults ---> adult ---> None
# and ---> and ---> None
# children ---> child ---> None
# . ---> . ---> None
#
#  --->
#  ---> None
# We ---> we ---> None
# ’ve ---> ’ve ---> None
# found ---> find ---> None
# evidence ---> evidence ---> None
# that ---> that ---> None
# people ---> people ---> None
# care ---> care ---> None
# about ---> about ---> None
# both ---> both ---> None
# themselves ---> themselves ---> None
# and ---> and ---> None
# others ---> other ---> None
# – ---> – ---> None
# but ---> but ---> None
# it ---> it ---> None
# ’s ---> ’ ---> None
# the ---> the ---> None
# self ---> self ---> None
# that ---> that ---> None
# takes ---> take ---> None
# precedence ---> precedence ---> None
# . ---> . ---> None
# Children ---> child ---> None
# are ---> be ---> None
# sensitive ---> sensitive ---> None
# to ---> to ---> None
# fairness ---> fairness ---> None
# from ---> from ---> None
# a ---> a ---> None
# very ---> very ---> None
# early ---> early ---> None
# age ---> age ---> None
# . ---> . ---> None
# For ---> for ---> None
# instance ---> instance ---> None
# , ---> , ---> None
# if ---> if ---> None
# you ---> you ---> None
# give ---> give ---> None
# two ---> two ---> None
# siblings ---> sibling ---> None
# different ---> different ---> None
# numbers ---> number ---> None
# of ---> of ---> None
# cookies ---> cookie ---> None
# , ---> , ---> None
# the ---> the ---> None
# one ---> one ---> None
# who ---> who ---> None
# receives ---> receive ---> None
# fewer ---> few ---> None
# will ---> will ---> None
# likely ---> likely ---> None
# throw ---> throw ---> None
# a ---> a ---> None
# fit ---> fit ---> None
# . ---> . ---> None
#
#  --->
#  ---> None
# This ---> this ---> None
# shift ---> shift ---> None
# toward ---> toward ---> None
# equity ---> equity ---> None
# appears ---> appear ---> None
# to ---> to ---> None
# be ---> be ---> None
# universal ---> universal ---> None
# in ---> in ---> None
# humans ---> human ---> None
# and ---> and ---> None
# follows ---> follow ---> None
# similar ---> similar ---> None
# patterns ---> pattern ---> None
# across ---> across ---> None
# cultures ---> culture ---> None
# . ---> . ---> None
# Interestingly ---> interestingly ---> None
# , ---> , ---> None
# it ---> it ---> None
# takes ---> take ---> None
# several ---> several ---> None
# years ---> year ---> None
# of ---> of ---> None
# development ---> development ---> None
# before ---> before ---> None
# children ---> child ---> None
# ’s ---> ’s ---> None
# own ---> own ---> None
# behavior ---> behavior ---> None
# catches ---> catch ---> None
# up ---> up ---> None
# with ---> with ---> None
# their ---> their ---> None
# understanding ---> understanding ---> None
# of ---> of ---> None
# fairness ---> fairness ---> None
# – ---> – ---> None
# for ---> for ---> None
# instance ---> instance ---> None
# , ---> , ---> None
# by ---> by ---> None
# opting ---> opt ---> None
# to ---> to ---> None
# share ---> share ---> None
# resources ---> resource ---> None
# more ---> more ---> None
# equally ---> equally ---> None
# rather ---> rather ---> None
# than ---> than ---> None
# prioritizing ---> prioritize ---> None
# their ---> their ---> None
# own ---> own ---> None
# payoffs ---> payoff ---> None
# . ---> . ---> None
# To ---> to ---> None
# investigate ---> investigate ---> None
# how ---> how ---> None
# children ---> child ---> None
# ’s ---> ’s ---> None
# developing ---> develop ---> None
# brains ---> brain ---> None
# guide ---> guide ---> None
# their ---> their ---> None
# understanding ---> understanding ---> None
# of ---> of ---> None
# fairness ---> fairness ---> None
# , ---> , ---> None
# we ---> we ---> None
# invited ---> invite ---> None
# kids ---> kid ---> None
# ranging ---> range ---> None
# from ---> from ---> None
# age ---> age ---> None
# 4 ---> 4 ---> None
# to ---> to ---> None
# 8 ---> 8 ---> None
# into ---> into ---> None
# our ---> our ---> None
# lab ---> lab ---> None
# . ---> . ---> None
#
#  --->
#  ---> None
# After ---> after ---> None
# they ---> they ---> None
# decided ---> decide ---> None
# how ---> how ---> None
# many ---> many ---> None
# ( ---> ( ---> None
# if ---> if ---> None
# any ---> any ---> None
# ) ---> ) ---> None
# to ---> to ---> None
# share ---> share ---> None
# , ---> , ---> None
# we ---> we ---> None
# measured ---> measure ---> None
# their ---> their ---> None
# brain ---> brain ---> None
# activity ---> activity ---> None
# using ---> use ---> None
# noninvasive ---> noninvasive ---> None
# electroencephalography ---> electroencephalography ---> None
# while ---> while ---> None
# they ---> they ---> None
# watched ---> watch ---> None
# an ---> an ---> None
# adult ---> adult ---> None
# split ---> split ---> None
# 10 ---> 10 ---> None
# rewards ---> reward ---> None
# – ---> – ---> None
# like ---> like ---> None
# candies ---> candy ---> None
# , ---> , ---> None
# coins ---> coin ---> None
# or ---> or ---> None
# stickers ---> sticker ---> None
# – ---> – ---> None
# between ---> between ---> None
# two ---> two ---> None
# other ---> other ---> None
# people ---> people ---> None
# . ---> . ---> None
#
#  --->
#  ---> None
# After ---> after ---> None
# 400 ---> 400 ---> None
# milliseconds ---> millisecond ---> None
# , ---> , ---> None
# the ---> the ---> None
# brain ---> brain ---> None
# electrical ---> electrical ---> None
# activity ---> activity ---> None
# for ---> for ---> None
# kids ---> kid ---> None
# who ---> who ---> None
# saw ---> see ---> None
# the ---> the ---> None
# slightly ---> slightly ---> None
# unfair ---> unfair ---> None
# 7:3 ---> 7:3 ---> None
# split ---> split ---> None
# changed ---> change ---> None
# to ---> to ---> None
# look ---> look ---> None
# like ---> like ---> None
# the ---> the ---> None
# brain ---> brain ---> None
# response ---> response ---> None
# of ---> of ---> None
# kids ---> kid ---> None
# who ---> who ---> None
# saw ---> see ---> None
# the ---> the ---> None
# completely ---> completely ---> None
# fair ---> fair ---> None
# 5:5 ---> 5:5 ---> None
# division ---> division ---> None
# . ---> . ---> None
# Our ---> our ---> None
# interpretation ---> interpretation ---> None
# is ---> be ---> None
# that ---> that ---> None
# the ---> the ---> None
# young ---> young ---> None
# brains ---> brain ---> None
# used ---> use ---> None
# that ---> that ---> None
# short ---> short ---> None
# lag ---> lag ---> None
# time ---> time ---> None
# to ---> to ---> None
# consider ---> consider ---> None
# why ---> why ---> None
# an ---> an ---> None
# adult ---> adult ---> None
# might ---> might ---> None
# have ---> have ---> None
# handed ---> hand ---> None
# out ---> out ---> None
# the ---> the ---> None
# treats ---> treat ---> None
# in ---> in ---> None
# a ---> a ---> None
# slightly ---> slightly ---> None
# unfair ---> unfair ---> None
# way ---> way ---> None
# and ---> and ---> None
# then ---> then ---> None
# resolved ---> resolve ---> None
# that ---> that ---> None
# it ---> it ---> None
# may ---> may ---> None
# actually ---> actually ---> None
# have ---> have ---> None
# been ---> be ---> None
# fair ---> fair ---> None
# . ---> . ---> None
# Further ---> far ---> None
# , ---> , ---> None
# children ---> child ---> None
# whose ---> whose ---> None
# brain ---> brain ---> None
# activity ---> activity ---> None
# patterns ---> pattern ---> None
# were ---> be ---> None
# the ---> the ---> None
# most ---> most ---> None
# different ---> different ---> None
# when ---> when ---> None
# viewing ---> view ---> None
# fair ---> fair ---> None
# versus ---> versus ---> None
# unfair ---> unfair ---> None
# distributions ---> distribution ---> None
# were ---> be ---> None
# the ---> the ---> None
# most ---> most ---> None
# likely ---> likely ---> None
# to ---> to ---> None
# have ---> have ---> None
# used ---> use ---> None
# merit ---> merit ---> None
# and ---> and ---> None
# need ---> need ---> None
# when ---> when ---> None
# they ---> they ---> None
# originally ---> originally ---> None
# divided ---> divide ---> None
# up ---> up ---> None
# their ---> their ---> None
# candies ---> candy ---> None
# , ---> , ---> None
# before ---> before ---> None
# they ---> they ---> None
# watched ---> watch ---> None
# the ---> the ---> None
# adults ---> adult ---> None
# . ---> . ---> None
# So ---> so ---> None
# the ---> the ---> None
# EEG ---> EEG ---> None
# recordings ---> recording ---> None
# indicate ---> indicate ---> None
# that ---> that ---> None
# even ---> even ---> None
# 4 ---> 4 ---> None
# - ---> - ---> None
# year ---> year ---> None
# - ---> - ---> None
# old ---> old ---> None
# children ---> child ---> None
# expect ---> expect ---> None
# distributions ---> distribution ---> None
# to ---> to ---> None
# be ---> be ---> None
# perfectly ---> perfectly ---> None
# equal ---> equal ---> None
# , ---> , ---> None
# which ---> which ---> None
# makes ---> make ---> None
# sense ---> sense ---> None
# given ---> give ---> None
# their ---> their ---> None
# natural ---> natural ---> None
# preference ---> preference ---> None
# for ---> for ---> None
# equality ---> equality ---> None
# . ---> . ---> None

# %% [markdown]
# ## Sentence Boundary Detection

# %%
list(doc.sents)
# Out:
# [Together they facilitate cooperation among unrelated individuals, something ubiquitous among people but uncommon in nature.,
#  A critical question is how people balance these two motivations when making decisions.,
#  We investigate this question in our work at the Social Cognitive Neuroscience Laboratory at the University of Chicago, combining behavioral economics tasks with neuroimaging methods that let us watch what’s happening in the brains of adults and children.,
#  ,
#  We’ve found evidence that people care about both themselves and others – but it’s the self that takes precedence.,
#  Children are sensitive to fairness from a very early age.,
#  For instance, if you give two siblings different numbers of cookies, the one who receives fewer will likely throw a fit.,
#  ,
#  This shift toward equity appears to be universal in humans and follows similar patterns across cultures.,
#  Interestingly, it takes several years of development before children’s own behavior catches up with their understanding of fairness – for instance, by opting to share resources more equally rather than prioritizing their own payoffs.,
#  To investigate how children’s developing brains guide their understanding of fairness, we invited kids ranging from age 4 to 8 into our lab.,
#  ,
#  After they decided how many (if any) to share, we measured their brain activity using noninvasive electroencephalography while they watched an adult split 10 rewards – like candies, coins or stickers – between two other people.,
#  ,
#  After 400 milliseconds, the brain electrical activity for kids who saw the slightly unfair 7:3 split changed to look like the brain response of kids who saw the completely fair 5:5 division.,
#  Our interpretation is that the young brains used that short lag time to consider why an adult might have handed out the treats in a slightly unfair way and then resolved that it may actually have been fair.,
#  Further, children whose brain activity patterns were the most different when viewing fair versus unfair distributions were the most likely to have used merit and need when they originally divided up their candies, before they watched the adults.,
#  So the EEG recordings indicate that even 4-year-old children expect distributions to be perfectly equal, which makes sense given their natural preference for equality.]

# %%
sentences = list(doc.sents)

# %%
for sentence in sentences:
    print(sentence)
# Out:
# Together they facilitate cooperation among unrelated individuals, something ubiquitous among people but uncommon in nature.
# A critical question is how people balance these two motivations when making decisions.
# We investigate this question in our work at the Social Cognitive Neuroscience Laboratory at the University of Chicago, combining behavioral economics tasks with neuroimaging methods that let us watch what’s happening in the brains of adults and children.
#
#
# We’ve found evidence that people care about both themselves and others – but it’s the self that takes precedence.
# Children are sensitive to fairness from a very early age.
# For instance, if you give two siblings different numbers of cookies, the one who receives fewer will likely throw a fit.
#
#
# This shift toward equity appears to be universal in humans and follows similar patterns across cultures.
# Interestingly, it takes several years of development before children’s own behavior catches up with their understanding of fairness – for instance, by opting to share resources more equally rather than prioritizing their own payoffs.
# To investigate how children’s developing brains guide their understanding of fairness, we invited kids ranging from age 4 to 8 into our lab.
#
#
# After they decided how many (if any) to share, we measured their brain activity using noninvasive electroencephalography while they watched an adult split 10 rewards – like candies, coins or stickers – between two other people.
#
#
# After 400 milliseconds, the brain electrical activity for kids who saw the slightly unfair 7:3 split changed to look like the brain response of kids who saw the completely fair 5:5 division.
# Our interpretation is that the young brains used that short lag time to consider why an adult might have handed out the treats in a slightly unfair way and then resolved that it may actually have been fair.
# Further, children whose brain activity patterns were the most different when viewing fair versus unfair distributions were the most likely to have used merit and need when they originally divided up their candies, before they watched the adults.
# So the EEG recordings indicate that even 4-year-old children expect distributions to be perfectly equal, which makes sense given their natural preference for equality.

# %% [markdown]
# ## Named Entity

# %%
for ent in doc.ents:
    print(ent.text, '---->', ent.label, '---->', spacy.explain(ent.label))
# Out:
# two ----> 397 ----> None
# the Social Cognitive Neuroscience Laboratory ----> 383 ----> None
# the University of Chicago ----> 383 ----> None
# two ----> 397 ----> None
# several years ----> 391 ----> None
# age 4 to 8 ----> 391 ----> None
# 10 ----> 397 ----> None
# two ----> 397 ----> None
# 400 milliseconds ----> 395 ----> None
# 7:3 ----> 397 ----> None
# 5:5 ----> 397 ----> None
# EEG ----> 383 ----> None
# 4-year-old ----> 391 ----> None

# %% [markdown]
# ## Visualization

# %%
from spacy import displacy

# %%
displacy.render(doc, style='ent', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Together they facilitate cooperation among unrelated individuals, something ubiquitous among people but uncommon in nature.A critical question is how people balance these
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     two
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  motivations when making decisions.We investigate this question in our work at
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Social Cognitive Neuroscience Laboratory
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  at
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the University of Chicago
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , combining behavioral economics tasks with neuroimaging methods that let us watch what’s happening in the brains of adults and children.</br>We’ve found evidence that people care about both themselves and others – but it’s the self that takes precedence.Children are sensitive to fairness from a very early age.For instance, if you give
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     two
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  siblings different numbers of cookies, the one who receives fewer will likely throw a fit.</br>This shift toward equity appears to be universal in humans and follows similar patterns across cultures.Interestingly, it takes
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     several years
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  of development before children’s own behavior catches up with their understanding of fairness – for instance, by opting to share resources more equally rather than prioritizing their own payoffs.To investigate how children’s developing brains guide their understanding of fairness, we invited kids ranging from
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     age 4 to 8
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  into our lab.</br>After they decided how many (if any) to share, we measured their brain activity using noninvasive electroencephalography while they watched an adult split
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     10
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  rewards – like candies, coins or stickers – between
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     two
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  other people.</br>After
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     400 milliseconds
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
# , the brain electrical activity for kids who saw the slightly unfair
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     7:3
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  split changed to look like the brain response of kids who saw the completely fair
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     5:5
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  division.Our interpretation is that the young brains used that short lag time to consider why an adult might have handed out the treats in a slightly unfair way and then resolved that it may actually have been fair.Further, children whose brain activity patterns were the most different when viewing fair versus unfair distributions were the most likely to have used merit and need when they originally divided up their candies, before they watched the adults.So the
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     EEG
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  recordings indicate that even
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     4-year-old
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  children expect distributions to be perfectly equal, which makes sense given their natural preference for equality.</div></span>

# %%
displacy.render(doc, style='dep', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="3c9e804d5bd3495c97fe8cbc88301207-0" class="displacy" width="63750" height="1712.0" direction="ltr" style="max-width: none; height: 1712.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1622.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Together</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1622.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">they</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1622.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">facilitate</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1622.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">cooperation</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1622.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">among</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1622.0">
#     <tspan class="displacy-word" fill="currentColor" x="925">unrelated</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1622.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">individuals,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1622.0">
#     <tspan class="displacy-word" fill="currentColor" x="1275">something</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1622.0">
#     <tspan class="displacy-word" fill="currentColor" x="1450">ubiquitous</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1622.0">
#     <tspan class="displacy-word" fill="currentColor" x="1625">among</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1622.0">
#     <tspan class="displacy-word" fill="currentColor" x="1800">people</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1622.0">
#     <tspan class="displacy-word" fill="currentColor" x="1975">but</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1622.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">uncommon</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1622.0">
#     <tspan class="displacy-word" fill="currentColor" x="2325">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1622.0">
#     <tspan class="displacy-word" fill="currentColor" x="2500">nature.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2500">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1622.0">
#     <tspan class="displacy-word" fill="currentColor" x="2675">A</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2675">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1622.0">
#     <tspan class="displacy-word" fill="currentColor" x="2850">critical</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1622.0">
#     <tspan class="displacy-word" fill="currentColor" x="3025">question</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3025">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1622.0">
#     <tspan class="displacy-word" fill="currentColor" x="3200">is</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1622.0">
#     <tspan class="displacy-word" fill="currentColor" x="3375">how</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3375">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1622.0">
#     <tspan class="displacy-word" fill="currentColor" x="3550">people</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3550">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1622.0">
#     <tspan class="displacy-word" fill="currentColor" x="3725">balance</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3725">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1622.0">
#     <tspan class="displacy-word" fill="currentColor" x="3900">these</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3900">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1622.0">
#     <tspan class="displacy-word" fill="currentColor" x="4075">two</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4075">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1622.0">
#     <tspan class="displacy-word" fill="currentColor" x="4250">motivations</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4250">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1622.0">
#     <tspan class="displacy-word" fill="currentColor" x="4425">when</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4425">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1622.0">
#     <tspan class="displacy-word" fill="currentColor" x="4600">making</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4600">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1622.0">
#     <tspan class="displacy-word" fill="currentColor" x="4775">decisions.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4775">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1622.0">
#     <tspan class="displacy-word" fill="currentColor" x="4950">We</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4950">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1622.0">
#     <tspan class="displacy-word" fill="currentColor" x="5125">investigate</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="5125">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1622.0">
#     <tspan class="displacy-word" fill="currentColor" x

# %% [markdown]
# ## Putting it all together

# %%
lis = []

# %%
for token in doc:
    dic = {}
    dic['Token'] = token.text
    dic['POS'] = token.pos_
    dic['Tags'] = token.tag_
    dic['Dep'] = token.dep_
    dic['Explanation'] = spacy.explain(token.tag_)
    lis.append(dic)

# %%
import pandas as pd

# %%
data = pd.DataFrame(lis)

# %%
data
# Out:
#            Token    POS Tags     Dep  \
# 0       Together    ADV   RB  advmod
# 1           they   PRON  PRP   nsubj
# 2     facilitate   VERB  VBP    ROOT
# 3    cooperation   NOUN   NN    dobj
# 4          among    ADP   IN    prep
# ..           ...    ...  ...     ...
# 394      natural    ADJ   JJ    amod
# 395   preference   NOUN   NN    pobj
# 396          for    ADP   IN    prep
# 397     equality   NOUN   NN    pobj
# 398            .  PUNCT    .   punct
#
#                                    Explanation
# 0                                       adverb
# 1                            pronoun, personal
# 2        verb, non-3rd person singular present
# 3                       noun, singular or mass
# 4    conjunction, subordinating or preposition
# ..                                         ...
# 394                                  adjective
# 395                     noun, singular or mass
# 396  conjunction, subordinating or preposition
# 397                     noun, singular or mass
# 398          punctuation mark, sentence closer
#
# [399 rows x 5 columns]

# %% [markdown]
# #### You can reindex if you do not like the arrangement

# %%
l = []
for ent in doc.ents:
    d = {}
    d['entities'] = ent.text
    d['labels'] = ent.label_
    d['Explanation'] = spacy.explain(ent.label_)
    l.append(d)

# %%
entities = pd.DataFrame(l)

# %%
entities
# Out:
#                                         entities    labels  \
# 0                                            two  CARDINAL
# 1   the Social Cognitive Neuroscience Laboratory       ORG
# 2                      the University of Chicago       ORG
# 3                                            two  CARDINAL
# 4                                  several years      DATE
# 5                                     age 4 to 8      DATE
# 6                                             10  CARDINAL
# 7                                            two  CARDINAL
# 8                               400 milliseconds  QUANTITY
# 9                                            7:3  CARDINAL
# 10                                           5:5  CARDINAL
# 11                                           EEG       ORG
# 12                                    4-year-old      DATE
#
#                                      Explanation
# 0   Numerals that do not fall under another type
# 1        Companies, agencies, institutions, etc.
# 2        Companies, agencies, institutions, etc.
# 3   Numerals that do not fall under another type
# 4          Absolute or relative dates or periods
# 5          Absolute or relative dates or periods
# 6   Numerals that do not fall under another type
# 7   Numerals that do not fall under another type
# 8         Measurements, as of weight or distance
# 9   Numerals that do not fall under another type
# 10  Numerals that do not fall under another type
# 11       Companies, agencies, institutions, etc.
# 12         Absolute or relative dates or periods

# %%
entities.to_csv('NLPTasks', index = False)
